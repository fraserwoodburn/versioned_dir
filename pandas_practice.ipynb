# %%
import pandas as pd

# %%
df = "https://milliams.com/courses/data_analysis_python/cetml1659on.txt"
df = pd.read_csv(df,
           skiprows=6,
           delim_whitespace=True,
                na_values=["-99.9", "-99.99"])
df
# Out:
#       JAN  FEB  MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  DEC  \
# 1659  3.0  4.0  6.0   7.0  11.0  13.0  16.0  16.0  13.0  10.0   5.0  2.0
# 1660  0.0  4.0  6.0   9.0  11.0  14.0  15.0  16.0  13.0  10.0   6.0  5.0
# 1661  5.0  5.0  6.0   8.0  11.0  14.0  15.0  15.0  13.0  11.0   8.0  6.0
# 1662  5.0  6.0  6.0   8.0  11.0  15.0  15.0  15.0  13.0  11.0   6.0  3.0
# 1663  1.0  1.0  5.0   7.0  10.0  14.0  15.0  15.0  13.0  10.0   7.0  5.0
# 1664  4.0  5.0  5.0   8.0  11.0  15.0  16.0  16.0  13.0   9.0   6.0  4.0
# 1665  1.0  1.0  5.0   7.0  10.0  14.0  16.0  15.0  13.0   9.0   6.0  2.0
# 1666  4.0  5.0  6.0   8.0  11.0  15.0  18.0  17.0  14.0  11.0   6.0  3.0
# 1667  0.0  4.0  2.0   7.0  10.0  15.0  17.0  16.0  13.0   9.0   6.0  3.0
# 1668  5.0  5.0  5.0   8.0  10.0  14.0  16.0  16.0  14.0  10.0   6.0  5.0
# 1669  1.0  4.0  5.0   7.0  11.0  15.0  17.0  16.0  14.0  10.0   6.0  2.0
# 1670  3.0  1.0  5.0   8.0  11.0  14.0  16.0  16.0  14.0  10.0   6.0  3.0
# ...

# %%
df.plot()

# %%
tips = pd.read_csv("https://milliams.com/courses/data_analysis_python/tips.csv")
tips
# Out:
#      total_bill   tip   day    time  size
# 0         16.99  0.71   Sun  Dinner     2
# 1         10.34  1.16   Sun  Dinner     3
# 2         21.01  2.45   Sun  Dinner     3
# 3         23.68  2.32   Sun  Dinner     2
# 4         24.59  2.53   Sun  Dinner     4
# ..          ...   ...   ...     ...   ...
# 239       29.03  4.14   Sat  Dinner     3
# 240       27.18  1.40   Sat  Dinner     2
# 241       22.67  1.40   Sat  Dinner     2
# 242       17.82  1.22   Sat  Dinner     2
# 243       18.78  2.10  Thur  Dinner     2
#
# [244 rows x 5 columns]

# %%
tips["size"]
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
# 5      4
# 6      2
# 7      4
# 8      2
# 9      2
# 10     2
# 11     4
# 12     2
# 13     4
# 14     2
# 15     2
# 16     3
# 17     3
# 18     3
# 19     3
# 20     2
# 21     2
# 22     2
# 23     4
# 24     2
# 25     4
# 26     2
# 27     2
# 28     2
# 29     2
#       ..
# 214    3
# 215    2
# 216    5
# 217    2
# 218    2
# 219    4
# 220    2
# 221    2
# 222    1
# 223    3
# 224    2
# 225    2
# 226    2
# 227    4
# 228    2
# 229    2
# 230    4
# 231    3
# 232    2
# 233    2
# 234    2
# 235    2
# 236    2
# 237    2
# 238    3
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
tips.head()
# Out:
#    total_bill   tip  day    time  size
# 0       16.99  0.71  Sun  Dinner     2
# 1       10.34  1.16  Sun  Dinner     3
# 2       21.01  2.45  Sun  Dinner     3
# 3       23.68  2.32  Sun  Dinner     2
# 4       24.59  2.53  Sun  Dinner     4

# %%
size=tips["size"]
size.head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    4
# Name: size, dtype: int64

# %%
tips["total_bill"].min
# Out:
# <bound method Series.min of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
index_min_bill = tips["total_bill"].idxmin()
tips.loc[index_min_bill]
# Out:
# total_bill      3.07
# tip              0.7
# day              Sat
# time          Dinner
# size               1
# Name: 67, dtype: object

# %%
index_min_tip = tips["tip"].idxmin()
tips.loc[index_min_tip]
# Out:
# total_bill      3.07
# tip              0.7
# day              Sat
# time          Dinner
# size               1
# Name: 67, dtype: object

# %%
tips.head()
# Out:
#    total_bill   tip  day    time  size
# 0       16.99  0.71  Sun  Dinner     2
# 1       10.34  1.16  Sun  Dinner     3
# 2       21.01  2.45  Sun  Dinner     3
# 3       23.68  2.32  Sun  Dinner     2
# 4       24.59  2.53  Sun  Dinner     4

# %%
SPH = (tips["total_bill"] / tips["size"])
SPH.head()
# Out:
# 0     8.495000
# 1     3.446667
# 2     7.003333
# 3    11.840000
# 4     6.147500
# dtype: float64

# %%
tips.head()
# Out:
#    total_bill   tip  day    time  size
# 0       16.99  0.71  Sun  Dinner     2
# 1       10.34  1.16  Sun  Dinner     3
# 2       21.01  2.45  Sun  Dinner     3
# 3       23.68  2.32  Sun  Dinner     2
# 4       24.59  2.53  Sun  Dinner     4

# %%
tips["SPH"] = SPH

# %%
tips.head()
# Out:
#    total_bill   tip  day    time  size        SPH
# 0       16.99  0.71  Sun  Dinner     2   8.495000
# 1       10.34  1.16  Sun  Dinner     3   3.446667
# 2       21.01  2.45  Sun  Dinner     3   7.003333
# 3       23.68  2.32  Sun  Dinner     2  11.840000
# 4       24.59  2.53  Sun  Dinner     4   6.147500

# %%
tips["percent_tip"] = (tips["tip"] / tips["total_bill"])*100
tips.head()
# Out:
#    total_bill   tip  day    time  size        SPH  percent_tip
# 0       16.99  0.71  Sun  Dinner     2   8.495000     4.178929
# 1       10.34  1.16  Sun  Dinner     3   3.446667    11.218569
# 2       21.01  2.45  Sun  Dinner     3   7.003333    11.661114
# 3       23.68  2.32  Sun  Dinner     2  11.840000     9.797297
# 4       24.59  2.53  Sun  Dinner     4   6.147500    10.288735

# %%
tips.head()
# Out:
#    total_bill   tip  day    time  size        SPH  percent_tip
# 0       16.99  0.71  Sun  Dinner     2   8.495000     4.178929
# 1       10.34  1.16  Sun  Dinner     3   3.446667    11.218569
# 2       21.01  2.45  Sun  Dinner     3   7.003333    11.661114
# 3       23.68  2.32  Sun  Dinner     2  11.840000     9.797297
# 4       24.59  2.53  Sun  Dinner     4   6.147500    10.288735

# %%
tips_sat = tips["day"] == "Sat"
tips[tips_sat]
sat = tips[tips["day"] == "Sat"]
thurs = tips[tips["day"] == "Thur"]

# %%
sat["tip"].mean()
# Out:
# 2.095402298850575

# %%
thurs["tip"].mean()
# Out:
# 1.9398387096774194

# %%
tips.plot()

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
! conda update seaborn

# %%
! conda update seaborn

# %%
# !conda update seaborn -y

# %%
# %matplotlib inline

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", size="size", style="time")
